# %%
import pandas as pd
import glob
import os

# %%
# Get a list of HTML files in the specified directory
directory_input = '/Users/weare/Documents/Sports Interactive/Football Manager 2024/fm data python/data input'
list_of_files = glob.glob(os.path.join(directory_input, '*.html'))

# Extract only the filenames without the directory path and extension
file_names = [os.path.basename(file)[:-5] for file in list_of_files]

print("List of files:", file_names)  # Print the list of file names to see what's in it

# Prompt the user for a file name input
while True:
    file_name = input("Enter the file name (without extension): ").strip()  # Get user input and remove leading/trailing whitespaces
    
    # Check if the entered filename exists in the list of file names
    if file_name in file_names:
        file_input_path = os.path.join(directory_input, file_name + '.html')  # Construct the full path of the HTML file
        staff_rawdata_list = pd.read_html(file_input_path, header=0, encoding="utf-8", keep_default_na=False)  # Read HTML data into a list of DataFrame objects
        print("File found and data loaded successfully.")
        break
    else:
        print("File not found. Please try again.")  # If the entered filename doesn't exist, prompt the user again
# Out:
# List of files: ['Scout', 'Striker']
# Enter the file name (without extension): Scout
# File found and data loaded successfully.

# %%
# Turn the list into a dataframe
staff_rawdata = staff_rawdata_list[0]

# %%
# Calculate DDM
staff_rawdata['ddm'] = (
    ( staff_rawdata['Det'] + 
     staff_rawdata['Dis'] + 
     staff_rawdata['Mot']) / 3)
staff_rawdata.ddm = staff_rawdata.ddm.round(1)

# %%
# Calculate Scout
staff_rawdata['scout'] = (
    (staff_rawdata['Ada'] +
    staff_rawdata['Judge A'] +
    staff_rawdata['Judge P']) / 3)

staff_rawdata.scout = staff_rawdata.scout.round(1)

staff_rawdata['scoutOv'] = ((staff_rawdata['scout']) + (staff_rawdata['ddm'])) / 2

staff_rawdata.scoutOv = staff_rawdata.scoutOv.round(1)

# %%
# Print out preview on notebook
staff_rawdata
# Out:
#     Inf                  Name Preferred Job                 Club  Ada  Det  \
# 0   FrA          Egon Coordes         Scout                        18   11
# 1   Wnt            Jim Lawlor         Scout                        15   14
# 2   Wnt       David Trezeguet         Scout                        18   19
# 3   Wnt           David Friio         Scout                        19   17
# 4   FrA           Søren Lerby         Scout                        18   20
# 5   Wnt         Steve Hitchen         Scout                        17   16
# 6   Wnt        Javier Ribalta         Scout                        16   14
# 7   Wnt        David Williams         Scout                        18   13
# 8   Wnt          Peter Braund         Scout                        15   15
# 9   Wnt    Brendan MacFarlane         Scout                        16   11
# 10  Wnt         John Marshall         Scout                        19    7
# 11             Luciano Cánepa         Scout               ASPIRE   16   13
# 12              Ruedi Zbinden         Scout                Basel   16   15
# 13             Emiliano Gallo         Scout         Boca Juniors   19    9
# 14  Wnt        Pasquale Ussia         Scout              Bologna   17   14
# 15  Wnt           Dario Rossi         Scout              Bologna   15   13
# 16  Wnt    Jakob Friis-Hansen         Scout             Bordeaux   18   12
# 17              Paulo Meneses         Scout                Braga   17   14
# 18  Wnt         Leroy McCourt         Scout             Brighton   17    9
# 19  Wnt               Tim Coe         Scout             Brighton   15   12
# 20  Wnt          Pablo Ibáñez         Scout             Brighton   17   19
# 21  Wnt         Pietro Pacini         Scout            Carrarese   20    7
# 22  Wnt  Victor de los Santos         Scout               Celaya   18    9
# 23            Neil McGuinness         Scout        Columbus Crew   18   14
# 24                Mauro Silva         Scout          Corinthians   15   13
# 25            Paul Montgomery         Scout       Crystal Palace   18   15
# 26            Igor Gabrijelić         Scout        Dinamo Zagreb   17   12
# 27  Wnt       Sebastian Frank         Scout  Eintracht Frankfurt   16   11
# 28  Wnt          Nicolai Adam         Scout  Eintracht Frankfurt   15   12
# 29         Maurizio Niccolini         Scout           Fiorentina   19   13
# 30            Ricardo Correia         Scout           Fluminense   20   10
# 31               Emre Utkucan         Scout       Galatasaray SK   15   16
# 32             Fritz Bischoff         Scout             Gladbach   20    7
# 33  Wnt      Maximilian Lüftl         Scout             Hannover   17   12
# 34  Wnt       Willi Kronhardt         Scout               Hertha   20   10
# 35               Babacar Wane         Scout               Hertha   15   16
# 36               Mark Prizant         Scout          Inter Miami   15   12
# 37            Lothar Strehlau         Scout            Karlsruhe   20   10
# 38                  Gaby Ruiz         Scout            Leeds Utd   18   11
# 39  Wnt       Javier Moreiras         Scout              Levante   16   13
# 40  Wnt           Chris Jones         Scout        Middlesbrough   15   15
# 41                Aldo Pecini         Scout               Modena   19    8
# 42          Kevin Cruickshank         Scout     New York City FC   17    7
# 43       Reinhold Hintermaier         Scout             Nürnberg   18   13
# 44       José Ignacio Navarro         Scout           Olympiacos   19   13
# 45            Rosario Argento         Scout              Palermo   16    6
# 46            Douglas Gramani         Scout            Palmeiras   20    9
# 47          Marcelo Francisco         Scout            Palmeiras   16   12
# 48  Wnt         Paul Hamilton         Scout                  QPR   17   10
# 49                Brian Carey         Scout              Reading   18   15
# 50           Jérôme Bonnissel         Scout               Rennes   15   15
# 51  Wnt        Nikolaos Nakas         Scout           Schalke 04   15    9
# 52           Salvatore Monaco         Scout             Shakhtar   17   16
# 53                  Matt Dyer         Scout          Southampton   15   11
# 54               Flávio Costa         Scout          Sporting CP   17   14
# 55         Gianmario Specchia         Scout               Torino   15   13
# 56  Wnt   Domenico Zinfollino         Scout               Torino   19   15
# 57                 Rob Newman         Scout             West Ham   15   13
# 58             Rudi Wojtowicz         Scout            Wolfsburg   15   11
# 59  Wnt        Matthias Kipke         Scout            Wolfsburg   18   10
#
#     Mot  Tac Knw  Dis  Judge A  ...  Mgm  Phy  SPC  SpS  TCo  Tec  Youth  \
# 0    14       12   16       16  ...    1    2    5    3    9    9     19
# 1     3       13    5       20  ...   16    1    9    3   10   10      3
# 2     4        6   10       19  ...    1    1    5    2    7    9     10
# 3     4        8   13       17  ...    6    4    8    3    7    6     12
# 4     5       12   16       15  ...   14    3    7    3   10    8      8
# 5     3       13   11       16  ...   13    2    9    3   10    9     14
# 6     8       14   10       19  ...   17    3   10    3   12    9     14
# 7     7       11    1       17  ...    3    1    9    3    1    1     18
# 8    10       12    8       16  ...   14    1    7    1    5    4     11
# 9     9       14    7       15  ...   11    3    6    4    8    8     15
# 10    8       11    5       16  ...    3    2    8    4    8    5     12
# 11    9        6   12       17  ...    6    3    8    2    7    8     14
# 12    6        9   10       18  ...   14    2    8    4    9    9      6
# 13    7        7   11       15  ...    6    3    6    2    7    7     17
# 14   11       13   12       17  ...    8    3    7    4   10    5      8
# 15   12       13    3       16  ...    7    1    8    3   10    8     15
# 16   15       15   14       16  ...   10    4    9    3   10    4     15
# 17    2       14    3       16  ...   13    3    9    3   11    9      9
# 18   13       11   11       15  ...    3    4    8    4   10    4      6
# 19    7       10   11       17  ...    7    3    8    2    9    6      7
# 20    7        9   19       15  ...    1    3    6    4    7    8     10
# 21    3        8    9       16  ...    2    4    7    3    8    7      9
# 22   12       12    3       17  ...    6    2    8    4    9    8     14
# 23   14        8    8       15  ...    5    4    1    3    7    8      7
# 24   12       13   11       16  ...    9    3    7    4    7    6      1
# 25   12       10   12       17  ...   15    3    9    3   10    9     15
# 26    2        9    4       15  ...   12    2    5    4    9    5     16
# 27    6       14    7       15  ...   12    3    4    4   11    6     14
# 28    6       11   17       16  ...    6    3    8    4    9    5      4
# 29    7       13    7       17  ...    8    3    9    4   12    9     14
# 30    9       10   17       17  ...    3    3    6    3    9    8      4
# 31    1       10   12       17  ...    8    4    6    3    6    8     16
# 32    1        9    8       16  ...    2    4    8    3   10    5      9
# 33    6       11   12       15  ...    6    3    8    3   12    6     17
# 34   13       10   12       15  ...   13    2    6    2    8    8     19
# 35    2        8   18       15  ...    5    2    6    4    6    7     12
# 36   11       11   14       16  ...   11    3    8    2    7    8     12
# 37   14       10   10       16  ...    8    1    7    2   12   10     14
# 38   14       15    2       18  ...    4    4    7    2   11    9     11
# 39    5       15   16       15  ...    4    4    8    3   11    6     14
# 40    7        8   18       16  ...    2    4    5    3    5    8     15
# 41    3        9    5       17  ...    8    3    5    2    8    8      8
# 42    5        8    3       17  ...    6    4    6    3    9    8      3
# 43    6        9   13       15  ...    5    3    3    4    8    8     20
# 44    5       13   15       17  ...   11    3    9    4   11    9      5
# 45    3        6    9       15  ...    6    3    7    3    6    6     20
# 46    7       12    8       16  ...    6    2    8    3    9    8      7
# 47    9       13   10       17  ...    6    4    6    3    6    9     14
# 48    6        9   10       15  ...    6    4    8    2    8    7     16
# 49    9       11   11       16  ...   12    2    8    2   10   13     17
# 50   12       10   11       16  ...   11    3    8    4    8    7      6
# 51   11        6    8       16  ...    3    3    7    3    6    5     14
# 52   13        9   11       18  ...    7    4    6    4   12   12     15
# 53    6       12   11       15  ...   13    2    8    2   10    8      9
# 54   12       10   15       16  ...   12    2    9    2    8    9     14
# 55    7       11   11       18  ...    5    2    8    3   10    6     12
# 56    9       12    6       18  ...    6    3    9    3    9    9     19
# 57    9       13   18       15  ...   10    2    6    3   10    9     12
# 58    7        9    6       16  ...   10    3    8    4    8    8     19
# 59    6        4    7       16  ...   16    3    7    3    6    7     11
#
#      ddm  scout  scoutOv
# 0   13.7   16.7     15.2
# 1    7.3   18.3     12.8
# 2   11.0   19.0     15.0
# 3   11.3   17.3     14.3
# 4   13.7   16.0     14.8
# 5   10.0   16.7     13.4
# 6   10.7   17.7     14.2
# 7    7.0   18.3     12.6
# 8   11.0   16.0     13.5
# 9    9.0   15.3     12.2
# 10   6.7   16.7     11.7
# 11  11.3   16.7     14.0
# 12  10.3   18.0     14.2
# 13   9.0   17.0     13.0
# 14  12.3   17.3     14.8
# 15   9.3   15.7     12.5
# 16  13.7   16.7     15.2
# 17   6.3   16.7     11.5
# 18  11.0   16.7     13.8
# 19  10.0   16.3     13.2
# 20  15.0   16.0     15.5
# 21   6.3   17.3     11.8
# 22   8.0   17.3     12.6
# 23  12.0   16.0     14.0
# 24  12.0   15.3     13.6
# 25  13.0   17.0     15.0
# 26   6.0   16.0     11.0
# 27   8.0   16.0     12.0
# 28  11.7   15.7     13.7
# 29   9.0   18.0     13.5
# 30  12.0   18.3     15.2
# 31   9.7   16.0     12.8
# 32   5.3   18.0     11.6
# 33  10.0   16.0     13.0
# 34  11.7   16.7     14.2
# 35  12.0   15.3     13.6
# 36  12.3   15.3     13.8
# 37  11.3   17.0     14.2
# 38   9.0   17.3     13.2
# 39  11.3   15.3     13.3
# 40  13.3   15.7     14.5
# 41   5.3   17.7     11.5
# 42   5.0   17.0     11.0
# 43  10.7   16.3     13.5
# 44  11.0   17.7     14.4
# 45   6.0   16.0     11.0
# 46   8.0   17.3     12.6
# 47  10.3   16.3     13.3
# 48   8.7   16.0     12.4
# 49  11.7   16.3     14.0
# 50  12.7   15.7     14.2
# 51   9.3   16.0     12.6
# 52  13.3   17.7     15.5
# 53   9.3   15.0     12.2
# 54  13.7   17.0     15.4
# 55  10.3   16.3     13.3
# 56  10.0   18.0     14.0
# 57  13.3   15.3     14.3
# 58   8.0   15.7     11.8
# 59   7.7   17.3     12.5
#
# [60 rows x 31 columns]

# %%
# builds squad dataframe using only columns that will be exported to HTML

staff = staff_rawdata[['Inf','Name','Preferred Job','Club','ddm','scout','scoutOv']]

# %%
# taken from here: https://www.thepythoncode.com/article/convert-pandas-dataframe-to-html-table-python
# creates a function to make a sortable html export

def generate_html(dataframe: pd.DataFrame):
    # get the table HTML from the dataframe
    table_html = dataframe.to_html(table_id="table")
    # construct the complete HTML with jQuery Data tables
    # You can disable paging or enable y scrolling on lines 20 and 21 respectively
    html = f"""
    <html>
    <header>
        <link href="https://cdn.datatables.net/1.11.5/css/jquery.dataTables.min.css" rel="stylesheet">
    </header>
    <body>
    {table_html}
    <script src="https://code.jquery.com/jquery-3.6.0.slim.min.js" integrity="sha256-u7e5khyithlIdTpu22PHhENmPcRdFiHRjhAuHcs05RI=" crossorigin="anonymous"></script>
    <script type="text/javascript" src="https://cdn.datatables.net/1.11.5/js/jquery.dataTables.min.js"></script>
    <script>
        $(document).ready( function () {{
            $('#table').DataTable({{
                // paging: false,    
                // scrollY: 400,
            }});
        }});
    </script>
    </body>
    </html>
    """
    # return the html
    return html

# %%
# generates random file name for write-out of html file
directory_output = '/Users/weare/Documents/Sports Interactive/Football Manager 2024/fm data python/output'

custom_filename = input("Enter the desired filename (without extension): ").strip()

file_output_path = os.path.join(directory_output, custom_filename + ".html")
# Out:
# Enter the desired filename (without extension): Scout Output

# %%
# creates a sortable html export from the dataframe 'squad'

html = generate_html(staff)
open(file_output_path, "w", encoding="utf-8").write(html)
# Out:
# 12272
